# %% [markdown]
# # CIFAR ResNet Infusion - Publication Figures for ICML 2026
#
# This notebook creates publication-ready figures for the ResNet CIFAR experiment section.
#
# **Figures to generate:**
# 1. Multiple Example Visualization (probe + training images)
# 2. Bar Chart with Temporal Distribution
# 3. Key Statistical Tests Summary (Tests 1, 3, 5)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle
import pandas as pd
import seaborn as sns
from glob import glob
from scipy import stats
from dotenv import load_dotenv

load_dotenv()

# Set publication-quality matplotlib parameters
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 8
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['axes.titlesize'] = 10
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 8
plt.rcParams['text.usetex'] = False  # Set to True if LaTeX is available

# Create figures directory
os.makedirs('figures', exist_ok=True)

print("Setup complete. Ready to generate figures.")

# %%
# Configuration
RESULTS_DIR = f'/scratch/s5e/{os.getenv("AUTHOR")}.s5e/infusion/cifar/results'
CLASS_NAMES = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
K = 10  # Number of classes

print(f"Results directory: {RESULTS_DIR}")

# %%
# Helper functions
def load_experiment_result(exp_dir):
    """Load a single experiment result"""
    result_path = os.path.join(exp_dir, 'results.npz')
    if os.path.exists(result_path):
        return np.load(result_path, allow_pickle=True)
    return None

def softmax(logits):
    """Compute softmax probabilities from logits"""
    exp_logits = np.exp(logits - np.max(logits, axis=-1, keepdims=True))
    return exp_logits / np.sum(exp_logits, axis=-1, keepdims=True)

def denormalize_cifar(img):
    """Denormalize CIFAR-10 image for visualization"""
    # Assuming img is in [0, 1] range
    return np.clip(img, 0, 1)

def show_cifar_image(ax, img, title=None):
    """Display a CIFAR-10 image on an axis"""
    # img should be (C, H, W), convert to (H, W, C)
    img_display = np.transpose(denormalize_cifar(img), (1, 2, 0))
    ax.imshow(img_display)
    ax.axis('off')
    if title:
        ax.set_title(title, fontsize=7)

print("Helper functions loaded.")
# Out:
# Helper functions loaded.

# %%
# Load experiment results - limit to first 2000 (200 probe images × 10 classes)
exp_dirs = sorted(glob(os.path.join(RESULTS_DIR, 'sample_*')))
print(f"Found {len(exp_dirs)} experiment directories")

# Limit to first 2000 experiments
exp_dirs = exp_dirs[:2000]
print(f"Using first {len(exp_dirs)} experiments (200 probe images × 10 classes)")

# Load subset for analysis
all_results = []
for exp_dir in exp_dirs:
    result = load_experiment_result(exp_dir)
    if result is not None:
        logits_pre = result['logits_epoch10'][0]
        logits_post = result['logits_infused'][0]
        p_pre = softmax(logits_pre)
        p_post = softmax(logits_post)
        target_class = int(result['target_class'])
        delta_p = p_post[target_class] - p_pre[target_class]
        
        all_results.append({
            'exp_dir': exp_dir,
            'result': result,
            'delta_p': delta_p,
            'target_class': target_class,
            'true_label': int(result['true_label']),
            'p_pre': p_pre,
            'p_post': p_post
        })

print(f"Loaded {len(all_results)} results")
# Out:
# Found 2404 experiment directories
# Using first 2000 experiments (200 probe images × 10 classes)
# Loaded 2000 results

# %% [markdown]
# ## Figure 1: Multiple Example Visualization
#
# Show 2-3 examples with probe image + top 5-10 training images (before/after perturbation)

# %%
# Select 3 examples: high delta_p, medium, and from different classes
sorted_results = sorted(all_results, key=lambda x: x['delta_p'], reverse=True)

# Select examples
example_indices = [
    0,  # Highest delta_p
    len(sorted_results) // 3,  # Upper-middle
    len(sorted_results) // 2,  # Median
]

selected_examples = [sorted_results[i] for i in example_indices]

# Show selected examples info
for i, ex in enumerate(selected_examples):
    print(f"\nExample {i+1}:")
    print(f"  Δp(target) = {ex['delta_p']:.4f}")
    print(f"  True label: {CLASS_NAMES[ex['true_label']]}")
    print(f"  Target class: {CLASS_NAMES[ex['target_class']]}")
    print(f"  p(target) before: {ex['p_pre'][ex['target_class']]:.4f}")
    print(f"  p(target) after: {ex['p_post'][ex['target_class']]:.4f}")
# Out:
# Example 1:
#   Δp(target) = 0.9643
#   True label: automobile
#   Target class: ship
#   p(target) before: 0.0159
#   p(target) after: 0.9802
#
# Example 2:
#   Δp(target) = 0.2783
#   True label: horse
#   Target class: airplane
#   p(target) before: 0.0003
#   p(target) after: 0.2786
#
# Example 3:
#   Δp(target) = 0.0916
#   True label: automobile
#   Target class: deer
#   p(target) before: 0.0001
#   p(target) after: 0.0916

# %%
# Create Figure 1: Multiple Examples
N_EXAMPLES = 3
N_TRAIN_SHOW = 5  # Show top 5 training images per example

fig = plt.figure(figsize=(7.0, 5.5))  # ICML two-column width is ~7 inches
gs = gridspec.GridSpec(N_EXAMPLES, N_TRAIN_SHOW + 2, figure=fig, 
                       hspace=0.4, wspace=0.3,
                       left=0.05, right=0.95, top=0.95, bottom=0.05)

for row_idx, example in enumerate(selected_examples):
    result = example['result']
    
    # Probe image
    ax_probe = fig.add_subplot(gs[row_idx, 0])
    probe_img = result['probe_image']
    show_cifar_image(ax_probe, probe_img, f"Probe\n{CLASS_NAMES[example['true_label']]}")
    
    # Add label for this row
    if row_idx == 0:
        ax_probe.text(-0.3, 0.5, f"Ex {row_idx+1}\nΔp={example['delta_p']:.3f}", 
                     transform=ax_probe.transAxes, ha='right', va='center', fontsize=7)
    else:
        ax_probe.text(-0.3, 0.5, f"Ex {row_idx+1}\nΔp={example['delta_p']:.3f}", 
                     transform=ax_probe.transAxes, ha='right', va='center', fontsize=7)
    
    # Top training images (original)
    orig_imgs = result['original_train_images']
    pert_imgs = result['perturbed_train_images']
    
    for i in range(N_TRAIN_SHOW):
        # Original (top half)
        ax_orig = fig.add_subplot(gs[row_idx, i + 1])
        title = f"Orig {i+1}" if row_idx == 0 else None
        show_cifar_image(ax_orig, orig_imgs[i], title)
        
        # Add small border to distinguish original
        for spine in ax_orig.spines.values():
            spine.set_edgecolor('blue')
            spine.set_linewidth(1)
    
    # Difference visualization in last column
    ax_diff = fig.add_subplot(gs[row_idx, -1])
    # Show amplified difference for first training image
    diff = pert_imgs[0] - orig_imgs[0]
    diff_amplified = np.clip(diff * 10 + 0.5, 0, 1)  # Amplify and center at 0.5
    show_cifar_image(ax_diff, diff_amplified, "Δ×10" if row_idx == 0 else None)
    
    # Add border to show it's a difference
    for spine in ax_diff.spines.values():
        spine.set_edgecolor('red')
        spine.set_linewidth(1)

# Add overall title
fig.suptitle('Infusion Examples: Probe Points and Selected Training Images', 
             fontsize=10, y=0.98)

plt.savefig('figures/figure1_example_visualization.pdf', bbox_inches='tight', dpi=300)
plt.savefig('figures/figure1_example_visualization.png', bbox_inches='tight', dpi=300)
print("\nFigure 1 saved to figures/figure1_example_visualization.pdf")
plt.show()
# Out:
# Figure 1 saved to figures/figure1_example_visualization.pdf

# %% [markdown]
# ## Figure 3: Bar Chart with Temporal Distribution
#
# Show probability distribution before/after for one example, plus temporal distribution of training examples

# %%
# Use the highest delta_p example
example = selected_examples[0]
result = example['result']

# Create figure with two panels
fig, axes = plt.subplots(1, 2, figsize=(7.0, 2.5))

# Left panel: Probability bar chart
ax_bar = axes[0]
x = np.arange(K)
width = 0.35

p_pre = example['p_pre']
p_post = example['p_post']
target_idx = example['target_class']
true_idx = example['true_label']

bars1 = ax_bar.bar(x - width/2, p_pre, width, label='Original (Epoch 10)', 
                   color='steelblue', alpha=0.8)
bars2 = ax_bar.bar(x + width/2, p_post, width, label='Infused', 
                   color='coral', alpha=0.8)

# Highlight target class
bars2[target_idx].set_edgecolor('red')
bars2[target_idx].set_linewidth(2)

ax_bar.set_xlabel('Class')
ax_bar.set_ylabel('Probability')
ax_bar.set_title(f'Probability Distribution (Δp={example["delta_p"]:.3f})')
ax_bar.set_xticks(x)
ax_bar.set_xticklabels([c[:3] for c in CLASS_NAMES], rotation=45, ha='right')
ax_bar.legend(loc='upper right', fontsize=7)
ax_bar.grid(axis='y', alpha=0.3)

# Add annotation for target
ax_bar.text(target_idx, max(p_post[target_idx], p_pre[target_idx]) * 1.05, 
           '★', ha='center', fontsize=12, color='red')

# Right panel: Temporal distribution
ax_temp = axes[1]
train_indices = result['selected_train_indices']
train_size = 45000  # Training set size

# Convert absolute indices to positions (0-1 scale)
positions = np.array(train_indices) / train_size

# Histogram of positions
ax_temp.hist(positions, bins=20, edgecolor='black', alpha=0.7, color='purple')
ax_temp.set_xlabel('Position in Training Set')
ax_temp.set_ylabel('Count')
ax_temp.set_title(f'Temporal Distribution of Top-{len(train_indices)} Examples')
ax_temp.grid(axis='y', alpha=0.3)

# Add vertical line at median
median_pos = np.median(positions)
ax_temp.axvline(median_pos, color='red', linestyle='--', linewidth=1, 
               label=f'Median={median_pos:.2f}')
ax_temp.legend(loc='upper right', fontsize=7)

plt.tight_layout()
plt.savefig('figures/figure3_bar_chart_temporal.pdf', bbox_inches='tight', dpi=300)
plt.savefig('figures/figure3_bar_chart_temporal.png', bbox_inches='tight', dpi=300)
print("\nFigure 3 saved to figures/figure3_bar_chart_temporal.pdf")
plt.show()
# Out:
# Figure 3 saved to figures/figure3_bar_chart_temporal.pdf

# %% [markdown]
# ## Figure 4: Key Statistical Tests Summary
#
# Show Tests 1, 3, and 5 in a compact 3-panel layout

# %%
# Recompute statistics from all results
delta_target = np.array([r['delta_p'] for r in all_results])

# Test 3: Log-odds change
log_odds_change = []
for r in all_results:
    p_pre = r['p_pre']
    p_post = r['p_post']
    t_i = r['target_class']
    
    non_target_mask = np.ones(K, dtype=bool)
    non_target_mask[t_i] = False
    
    p_bar_pre = p_pre[non_target_mask].mean()
    p_bar_post = p_post[non_target_mask].mean()
    
    L_pre = np.log(p_pre[t_i] / (p_bar_pre + 1e-10))
    L_post = np.log(p_post[t_i] / (p_bar_post + 1e-10))
    
    S_i = L_post - L_pre
    log_odds_change.append(S_i)

log_odds_change = np.array(log_odds_change)

# Test 5: Success rates
predicted_pre = np.array([np.argmax(r['p_pre']) for r in all_results])
predicted_post = np.array([np.argmax(r['p_post']) for r in all_results])
targets = np.array([r['target_class'] for r in all_results])

success_pre = (predicted_pre == targets)
success_post = (predicted_post == targets)

R_pre = success_pre.mean()
R_post = success_post.mean()

print(f"Test 1 - Mean Δp: {delta_target.mean():.4f}")
print(f"Test 3 - Mean log-odds: {log_odds_change.mean():.4f}")
print(f"Test 5 - Success rates: {R_pre:.4f} → {R_post:.4f}")
# Out:
# Test 1 - Mean Δp: 0.2322
# Test 3 - Mean log-odds: 5.1381
# Test 5 - Success rates: 0.1000 → 0.3735

# %%
# Create 3-panel figure
fig, axes = plt.subplots(1, 3, figsize=(7.0, 2.2))

# Panel 1: Test 1 - Target Probability Increase
ax1 = axes[0]
ax1.hist(delta_target, bins=40, edgecolor='black', alpha=0.7, color='steelblue')
ax1.axvline(0, color='red', linestyle='--', linewidth=1.5, label='Δp=0')
ax1.axvline(delta_target.mean(), color='green', linestyle='-', linewidth=1.5, 
           label=f'Mean={delta_target.mean():.3f}')
t_stat1, p_val1 = stats.ttest_1samp(delta_target, 0, alternative='greater')
ax1.set_xlabel('Δp(target)')
ax1.set_ylabel('Frequency')
ax1.set_title(f'Test 1: Target Increase\n(p<10$^{{-280}}$, d={delta_target.mean()/delta_target.std():.2f})', 
             fontsize=9)
ax1.legend(fontsize=6, loc='upper right')
ax1.grid(alpha=0.3)

# Panel 2: Test 3 - Log-Odds Change
ax2 = axes[1]
ax2.hist(log_odds_change, bins=40, edgecolor='black', alpha=0.7, color='coral')
ax2.axvline(0, color='red', linestyle='--', linewidth=1.5)
ax2.axvline(log_odds_change.mean(), color='green', linestyle='-', linewidth=1.5,
           label=f'Mean={log_odds_change.mean():.2f}')
cohens_d3 = log_odds_change.mean() / log_odds_change.std()
ax2.set_xlabel('Log-odds change')
ax2.set_ylabel('Frequency')
ax2.set_title(f'Test 3: Log-Odds\n(entropy-robust, d={cohens_d3:.2f})', fontsize=9)
ax2.legend(fontsize=6, loc='upper right')
ax2.grid(alpha=0.3)

# Panel 3: Test 5 - Success Rate
ax3 = axes[2]
labels = ['Before\nInfusion', 'After\nInfusion']
rates = [R_pre, R_post]
colors = ['steelblue', 'coral']
bars = ax3.bar(labels, rates, color=colors, edgecolor='black', alpha=0.8)

# Add value labels on bars
for bar, rate in zip(bars, rates):
    height = bar.get_height()
    ax3.text(bar.get_x() + bar.get_width()/2., height + 0.02,
            f'{rate:.1%}', ha='center', va='bottom', fontsize=8)

# Add change annotation
ax3.annotate('', xy=(1, R_post), xytext=(0, R_pre),
            arrowprops=dict(arrowstyle='->', lw=1.5, color='green'))
ax3.text(0.5, (R_pre + R_post)/2 + 0.05, f'+{(R_post-R_pre)*100:.1f}pp',
        ha='center', fontsize=8, color='green', weight='bold')

ax3.set_ylabel('Success Rate')
ax3.set_title('Test 5: Classification\n(McNemar p<10$^{-300}$)', fontsize=9)
ax3.set_ylim([0, max(rates) * 1.25])
ax3.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('figures/figure4_statistical_tests.pdf', bbox_inches='tight', dpi=300)
plt.savefig('figures/figure4_statistical_tests.png', bbox_inches='tight', dpi=300)
print("\nFigure 4 saved to figures/figure4_statistical_tests.pdf")
plt.show()
# Out:
# Figure 4 saved to figures/figure4_statistical_tests.pdf

# %% [markdown]
# ## Summary
#
# All publication figures have been generated:
# - **Figure 1**: Multiple example visualization (probe + training images)
# - **Figure 3**: Bar chart with temporal distribution
# - **Figure 4**: Key statistical tests summary
#
# Figures are saved in both PDF (vector) and PNG (raster) formats in the `figures/` directory.

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os

def create_probe_training_figure(example, n_show=5):
    """Figure 1: Probe image and negatively influential training examples (original, perturbed, difference)."""

    result = example['result']
    probe_image = result['probe_image']
    true_label = int(result['true_label'])
    target_class = int(result['target_class'])
    original_train_images = result['original_train_images']
    perturbed_train_images = result['perturbed_train_images']

    if 'original_train_labels' in result:
        original_train_labels = result['original_train_labels']
    else:
        original_train_labels = [0] * len(original_train_images)

    n_show = min(n_show, len(original_train_images))

    # --- Figure with probe image on left, 3 x n_show grid on right ---
    fig = plt.figure(figsize=(8, 3.5))
    left, right, top, bottom = 0.04, 0.98, 0.92, 0.08

    # Single row: Probe + Training Images
    gs_main = gridspec.GridSpec(
        1, 2,
        figure=fig,
        width_ratios=[1, n_show],
        left=left, right=right, top=top, bottom=bottom,
        wspace=0.4
    )

    # ---- Left: probe axes ----
    ax_probe = fig.add_subplot(gs_main[0, 0])
    show_cifar_image(ax_probe, probe_image)
    ax_probe.set_xticks([])
    ax_probe.set_yticks([])
    ax_probe.set_title("Probe Image", fontsize=10)

    for spine in ax_probe.spines.values():
        spine.set_visible(True)
        spine.set_edgecolor('black')
        spine.set_linewidth(2)

    # ---- Right: 3 x n_show grid ----
    gs_right = gridspec.GridSpecFromSubplotSpec(
        3, n_show,
        subplot_spec=gs_main[0, 1],
        hspace=0.06,
        wspace=0.06
    )

    ax_row0 = ax_row1 = ax_row2 = None
    ax_grid = []
    col_labels = []

    for i in range(n_show):
        label_i = original_train_labels[i]
        train_class_idx = int(label_i) if isinstance(label_i, (int, np.integer)) else None
        train_class = CLASS_NAMES[train_class_idx] if train_class_idx is not None else str(label_i)
        # Add asterisk after the text in the figure if the label is the target class
        if train_class_idx is not None and train_class_idx == target_class:
            col_labels.append(f"{train_class}*")
        else:
            col_labels.append(train_class)

        # Row 0: original
        ax_orig = fig.add_subplot(gs_right[0, i])
        show_cifar_image(ax_orig, original_train_images[i], None)

        # Row 1: perturbed
        ax_pert = fig.add_subplot(gs_right[1, i])
        show_cifar_image(ax_pert, perturbed_train_images[i])

        # Row 2: difference - colorful RGB (gray = no change)
        ax_diff = fig.add_subplot(gs_right[2, i])
        diff = perturbed_train_images[i] - original_train_images[i]
        diff_display = np.transpose(diff, (1, 2, 0))
        diff_amplified = np.clip(diff_display * 10 + 0.5, 0, 1)  # Gray (0.5) = no change, amplified x10
        ax_diff.imshow(diff_amplified)
        ax_diff.axis('off')

        if i == 0:
            ax_row0, ax_row1, ax_row2 = ax_orig, ax_pert, ax_diff

        ax_grid.append((ax_orig, ax_pert, ax_diff))

    # ---- Title above the 3 x n_show grid ----------------------------------
    if ax_grid:
        bbox0 = ax_grid[0][0].get_position()
        bboxN = ax_grid[-1][0].get_position()

        x0 = bbox0.x0
        xN = bboxN.x1
        x_center = 0.5 * (x0 + xN)
        y_top = bbox0.y1 + 0.02

        fig.text(
            x_center,
            y_top,
            f"Top k={n_show} most negatively influential training examples",
            ha='center', fontsize=10
        )

    # ---- Resize & align the probe axes ---------------------------------
    if ax_row0 is not None and ax_row2 is not None:
        bbox_top = ax_row0.get_position()
        bbox_bot = ax_row2.get_position()

        y0 = bbox_bot.y0
        y1 = bbox_top.y1
        height = y1 - y0

        # Get image aspect ratio
        if probe_image.ndim == 3:
            if probe_image.shape[0] in (1, 3):
                img_h, img_w = probe_image.shape[1], probe_image.shape[2]
            else:
                img_h, img_w = probe_image.shape[0], probe_image.shape[1]
        else:
            img_h, img_w = probe_image.shape
        img_ratio = img_w / img_h

        bbox_probe = ax_probe.get_position()
        x_center = 0.5 * (bbox_probe.x0 + bbox_probe.x1)
        width = height * img_ratio
        x0 = x_center - width / 2.0

        ax_probe.set_position([x0, y0, width, height])
        ax_probe.set_aspect('equal')

    # ---- Text for probe image ------------------------------

    # Probe label underneath
    bbox = ax_probe.get_position()
    # Add asterisk after target class *only*
    true_str = f"{CLASS_NAMES[true_label]}" + ("*" if true_label == target_class else "")
    target_str = f"{CLASS_NAMES[target_class]}*"
    fig.text(
        (bbox.x0 + bbox.x1) / 2,
        bbox.y0 - 0.02,
        f"True: {true_str}, Target: {target_str}",
        ha='center', va='top', fontsize=8
    )

    # Row labels between probe and grid
    if ax_row0 is not None:
        bbox_probe = ax_probe.get_position()
        bbox0 = ax_row0.get_position()
        bbox1 = ax_row1.get_position()
        bbox2 = ax_row2.get_position()

        x_label = (bbox_probe.x1 + bbox0.x0) / 2.0

        y0 = (bbox0.y0 + bbox0.y1) / 2.0
        y1 = (bbox1.y0 + bbox1.y1) / 2.0
        y2 = (bbox2.y0 + bbox2.y1) / 2.0

        fig.text(x_label, y0, 'Original',
                 fontsize=8, va='center', ha='center', rotation=90)
        fig.text(x_label, y1, 'Perturbed',
                 fontsize=8, va='center', ha='center', rotation=90)
        fig.text(x_label, y2, 'Difference (x10)',
                 fontsize=8, va='center', ha='center', rotation=90)

    # Column labels under each right-hand column, with asterisk if target class
    for i in range(n_show):
        ax_diff = ax_grid[i][2]
        bbox = ax_diff.get_position()
        x = (bbox.x0 + bbox.x1) / 2
        y = bbox.y0 - 0.015
        fig.text(x, y, col_labels[i],
                 ha='center', va='top', fontsize=8)

    return fig




sorted_results = sorted(all_results, key=lambda x: x['delta_p'], reverse=True)
selected_examples_2 = sorted_results

figures_dir = "figures"
os.makedirs(figures_dir, exist_ok=True)

for i, example_best in enumerate(selected_examples_2[:50]):
    if i == 37:
        # Create Figure 1: Probe image and training examples
        fig1 = create_probe_training_figure(example_best, n_show=5)
        fig1.savefig(os.path.join(figures_dir, "influence_figure1_probe_training.png"), bbox_inches='tight', dpi=200)
        fig1.savefig(os.path.join(figures_dir, "influence_figure1_probe_training.eps"), bbox_inches='tight', dpi=200)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os

def create_horizontal_training_figure(example, n_show=5):
    """Figure: n_show rows (each example) x 3 cols (Original, Perturbed, Diff). Now Nx3, i.e., n_show rows by 3 columns."""

    result = example['result']
    true_label = int(result['true_label'])
    target_class = int(result['target_class'])
    original_train_images = result['original_train_images']
    perturbed_train_images = result['perturbed_train_images']

    if 'original_train_labels' in result:
        original_train_labels = result['original_train_labels']
    else:
        original_train_labels = [0] * len(original_train_images)

    n_show = min(n_show, len(original_train_images))

    # --- Stack each type vertically (one column for each type), with n_show rows per column ---
    # Figure: n_show rows (examples), 3 columns (original, perturbed, diff)
    fig = plt.figure(figsize=(6, 2*n_show))
    left, right, top, bottom = 0.04, 0.98, 0.92, 0.08

    gs_main = gridspec.GridSpec(
        n_show, 3,
        figure=fig,
        left=left, right=right, top=top, bottom=bottom,
        hspace=0.18,
        wspace=0.16
    )

    row_labels = []
    for i in range(n_show):
        label_i = original_train_labels[i]
        train_class_idx = int(label_i) if isinstance(label_i, (int, np.integer)) else None
        train_class = CLASS_NAMES[train_class_idx] if train_class_idx is not None else str(label_i)
        # Add asterisk after the text in the figure if the label is the target class
        if train_class_idx is not None and train_class_idx == target_class:
            row_labels.append(f"{train_class}*")
        else:
            row_labels.append(train_class)

    col_labels = ["Original", "Perturbed", "Diff (x10)"]
    ax_grid = [[None for _ in range(3)] for _ in range(n_show)]
    for i in range(n_show):
        # Column 0: original
        ax_orig = fig.add_subplot(gs_main[i, 0])
        show_cifar_image(ax_orig, original_train_images[i], None)
        ax_orig.set_xticks([])
        ax_orig.set_yticks([])
        if i == 0:
            ax_orig.set_title(col_labels[0], fontsize=9, pad=7)
        ax_grid[i][0] = ax_orig

        # Column 1: perturbed
        ax_pert = fig.add_subplot(gs_main[i, 1])
        show_cifar_image(ax_pert, perturbed_train_images[i])
        ax_pert.set_xticks([])
        ax_pert.set_yticks([])
        if i == 0:
            ax_pert.set_title(col_labels[1], fontsize=9, pad=7)
        ax_grid[i][1] = ax_pert

        # Column 2: difference - colorful RGB (gray = no change)
        ax_diff = fig.add_subplot(gs_main[i, 2])
        diff = perturbed_train_images[i] - original_train_images[i]
        diff_display = np.transpose(diff, (1, 2, 0))
        diff_amplified = np.clip(diff_display * 10 + 0.5, 0, 1)  # Gray (0.5) = no change, amplified x10
        ax_diff.imshow(diff_amplified)
        ax_diff.axis('off')
        if i == 0:
            ax_diff.set_title(col_labels[2], fontsize=9, pad=7)
        ax_grid[i][2] = ax_diff

    # ---- Title above the grid ----------------------------------
    if n_show > 0:
        bbox0 = ax_grid[0][0].get_position()
        bboxN = ax_grid[0][2].get_position()

        x0 = bbox0.x0
        xN = bboxN.x1
        x_center = 0.5 * (x0 + xN)
        y_top = bbox0.y1 + 0.025

        fig.text(
            x_center,
            y_top,
            f"Top k={n_show} most negatively influential training examples (N rows: Each example; 3 columns: Original, Perturbed, Diff)",
            ha='center', fontsize=10
        )

    # ---- Class label to the left of each row ----
    for i in range(n_show):
        ax_orig = ax_grid[i][0]
        bbox = ax_orig.get_position()
        x = bbox.x0 - 0.02
        y = (bbox.y0 + bbox.y1) / 2
        fig.text(x, y, row_labels[i],
                 ha='right', va='center', fontsize=8)

    return fig




sorted_results = sorted(all_results, key=lambda x: x['delta_p'], reverse=True)
selected_examples_2 = sorted_results

figures_dir = "figures"
os.makedirs(figures_dir, exist_ok=True)

for i, example_best in enumerate(selected_examples_2[:50]):
    if i == 37:
        # Create horizontal stack (N rows: Each training example; 3 columns: Original, Perturbed, Diff)
        fig1 = create_horizontal_training_figure(example_best, n_show=5)
        fig1.savefig(os.path.join(figures_dir, "influence_figure1_training_horizontal.png"), bbox_inches='tight', dpi=200)
        fig1.savefig(os.path.join(figures_dir, "influence_figure1_training_horizontal.eps"), bbox_inches='tight', dpi=200)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib import gridspec

def create_model_comparison_figure(example):
    """Figure 2: Side-by-side vertical bar charts for Original and Infused Model probabilities."""

    sns.set_theme(style="whitegrid", context="paper")

    result = example["result"]
    true_label = int(result["true_label"])
    target_class = int(result["target_class"])

    p_pre = example["p_pre"]
    p_post = example["p_post"]

    K = len(CLASS_NAMES)

    # --- Sort classes alphabetically ---
    class_label_tuples = list(zip(CLASS_NAMES, p_pre, p_post, range(K)))
    class_label_tuples_sorted = sorted(class_label_tuples, key=lambda x: x[0])

    sorted_class_labels = [x[0] for x in class_label_tuples_sorted]
    p_pre_sorted = [x[1] for x in class_label_tuples_sorted]
    p_post_sorted = [x[2] for x in class_label_tuples_sorted]
    sorted_indices = [x[3] for x in class_label_tuples_sorted]

    # --- Collapse consecutive near-zero classes into "..." ---
    ZERO_THRESH = 0.01
    display_labels = []
    display_pre = []
    display_post = []
    display_indices = []
    in_collapse = False

    for j in range(len(sorted_class_labels)):
        is_zero = (p_pre_sorted[j] < ZERO_THRESH and p_post_sorted[j] < ZERO_THRESH)
        if is_zero:
            if not in_collapse:
                display_labels.append("...")
                display_pre.append(0)
                display_post.append(0)
                display_indices.append(None)
                in_collapse = True
        else:
            display_labels.append(sorted_class_labels[j])
            display_pre.append(p_pre_sorted[j])
            display_post.append(p_post_sorted[j])
            display_indices.append(sorted_indices[j])
            in_collapse = False

    def get_color(idx, true_label, target_class):
        if idx is None:
            return "#cccccc"  # gray for collapsed
        if idx == true_label:
            return "#377eb8"   # blue
        elif idx == target_class:
            return "#e41a1c"   # red
        else:
            return "#4daf4a"   # green

    palette = [get_color(idx, true_label, target_class) for idx in display_indices]

    # --- Figure layout (smaller canvas, bigger font) ---
    fig = plt.figure(figsize=(5, 2.5))
    gs = gridspec.GridSpec(
        1, 2,
        width_ratios=[1, 1],
        wspace=0.35,
        left=0.10,
        right=0.98,
        top=0.85,
        bottom=0.30
    )

    y_max = min(1.12, max(max(display_pre), max(display_post)) + 0.08)
    x = np.arange(len(display_labels))

    # --- Original Model ---
    ax_pre = fig.add_subplot(gs[0, 0])
    ax_pre.bar(x, display_pre, color=palette)
    ax_pre.set_title("Original Model", fontsize=11)
    ax_pre.set_ylabel("Probability", fontsize=10)
    ax_pre.set_ylim(0, y_max)
    ax_pre.set_xticks(x)
    ax_pre.set_xticklabels(display_labels, rotation=45, ha="right", fontsize=9)
    ax_pre.tick_params(axis='y', labelsize=9)

    # --- Infused Model ---
    ax_post = fig.add_subplot(gs[0, 1])
    ax_post.bar(x, display_post, color=palette)
    ax_post.set_title("Infused Model", fontsize=11)
    ax_post.set_ylabel("Probability", fontsize=10)
    ax_post.set_ylim(0, y_max)
    ax_post.set_xticks(x)
    ax_post.set_xticklabels(display_labels, rotation=45, ha="right", fontsize=9)
    ax_post.tick_params(axis='y', labelsize=9)

    # --- Legend ---
    legend_elements = [
        Patch(facecolor="#377eb8", label="True Class"),
        Patch(facecolor="#e41a1c", label="Target Class"),
        Patch(facecolor="#4daf4a", label="Other Classes"),
    ]
    # ax_pre.legend(
    #     handles=legend_elements,
    #     loc="upper right",
    #     fontsize=8,
    #     frameon=False
    # )
    # ax_post.legend(
    #     handles=legend_elements,
    #     loc="upper left",
    #     fontsize=8,
    #     frameon=False
    # )

    sns.despine(fig=fig)
    return fig



for i, example_best in enumerate(selected_examples_2[:50]):
    if i == 37:

        # Create Figure 2: Model comparison bar charts
        fig2 = create_model_comparison_figure(example_best)
        fig2.savefig(os.path.join(figures_dir, "influence_figure2_model_comparison.png"), bbox_inches='tight', dpi=200)
        fig2.savefig(os.path.join(figures_dir, "influence_figure2_model_comparison.eps"), bbox_inches='tight', dpi=200)

# %%
# Create a new figure showing the location of perturbed documents in the final retraining steps
# This shows where the perturbed documents lie in the training data stream

def create_influence_figure_with_timeline(example, n_show=5):
    """Figure with probe image, training images, bar chart, AND timeline of perturbed documents."""

    result = example['result']
    probe_image = result['probe_image']
    true_label = int(result['true_label'])
    target_class = int(result['target_class'])
    original_train_images = result['original_train_images']
    perturbed_train_images = result['perturbed_train_images']
    selected_train_indices = result['selected_train_indices']

    if 'original_train_labels' in result:
        original_train_labels = result['original_train_labels']
    else:
        original_train_labels = [0] * len(original_train_images)

    n_show = min(n_show, len(original_train_images))
    
    # Get probabilities
    p_pre = example['p_pre']
    p_post = example['p_post']
    target_idx = example['target_class']

    # --- Figure with 3 rows ---
    fig = plt.figure(figsize=(8, 7.5))
    left, right, top, bottom = 0.04, 0.98, 0.95, 0.06

    # Main grid: 3 rows
    # Row 0: probe + training images (height_ratios[0])
    # Row 1: bar chart (height_ratios[1])
    # Row 2: timeline (height_ratios[2]) - increased height for legend space
    gs_main = gridspec.GridSpec(
        3, 1,
        figure=fig,
        height_ratios=[2.5, 2, 0.8],
        left=left, right=right, top=top, bottom=bottom,
        hspace=0.6
    )

    # ===== ROW 0: Probe + Training Images =====
    gs_row0 = gridspec.GridSpecFromSubplotSpec(
        1, 2,
        subplot_spec=gs_main[0, 0],
        width_ratios=[1, n_show],
        wspace=0.4
    )

    # ---- Left: probe axes ----
    ax_probe = fig.add_subplot(gs_row0[0, 0])
    show_cifar_image(ax_probe, probe_image)
    ax_probe.set_xticks([])
    ax_probe.set_yticks([])
    ax_probe.set_title("Probe Image", fontsize=10)

    for spine in ax_probe.spines.values():
        spine.set_visible(True)
        spine.set_edgecolor('black')
        spine.set_linewidth(2)

    # ---- Right: 3 x n_show grid ----
    gs_right = gridspec.GridSpecFromSubplotSpec(
        3, n_show,
        subplot_spec=gs_row0[0, 1],
        hspace=0.06,
        wspace=0.06
    )

    ax_row0 = ax_row1 = ax_row2 = None
    ax_grid = []
    col_labels = []

    for i in range(n_show):
        label_i = original_train_labels[i]
        train_class_idx = int(label_i) if isinstance(label_i, (int, np.integer)) else None
        train_class = CLASS_NAMES[train_class_idx] if train_class_idx is not None else str(label_i)
        # Add asterisk after the text in the figure if the label is the target class
        if train_class_idx is not None and train_class_idx == target_class:
            col_labels.append(f"{train_class}*")
        else:
            col_labels.append(train_class)

        # Row 0: original
        ax_orig = fig.add_subplot(gs_right[0, i])
        show_cifar_image(ax_orig, original_train_images[i], None)

        # Row 1: perturbed
        ax_pert = fig.add_subplot(gs_right[1, i])
        show_cifar_image(ax_pert, perturbed_train_images[i])

        # Row 2: difference - colorful RGB (gray = no change)
        ax_diff = fig.add_subplot(gs_right[2, i])
        diff = perturbed_train_images[i] - original_train_images[i]
        diff_display = np.transpose(diff, (1, 2, 0))
        diff_amplified = np.clip(diff_display * 5 + 0.5, 0, 1)  # Gray (0.5) = no change
        ax_diff.imshow(diff_amplified)
        ax_diff.axis('off')

        if i == 0:
            ax_row0, ax_row1, ax_row2 = ax_orig, ax_pert, ax_diff

        ax_grid.append((ax_orig, ax_pert, ax_diff))

    # ---- Title above the 3 x n_show grid ----------------------------------
    if ax_grid:
        bbox0 = ax_grid[0][0].get_position()
        bboxN = ax_grid[-1][0].get_position()

        x0 = bbox0.x0
        xN = bboxN.x1
        x_center = 0.5 * (x0 + xN)
        y_top = bbox0.y1 + 0.02

        fig.text(
            x_center,
            y_top,
            f"Top k={n_show} most negatively influential training examples",
            ha='center', fontsize=10
        )

    # ---- Resize & align the probe axes ---------------------------------
    if ax_row0 is not None and ax_row2 is not None:
        bbox_top = ax_row0.get_position()
        bbox_bot = ax_row2.get_position()

        y0 = bbox_bot.y0
        y1 = bbox_top.y1
        height = y1 - y0

        # Get image aspect ratio
        if probe_image.ndim == 3:
            if probe_image.shape[0] in (1, 3):
                img_h, img_w = probe_image.shape[1], probe_image.shape[2]
            else:
                img_h, img_w = probe_image.shape[0], probe_image.shape[1]
        else:
            img_h, img_w = probe_image.shape
        img_ratio = img_w / img_h

        bbox_probe = ax_probe.get_position()
        x_center = 0.5 * (bbox_probe.x0 + bbox_probe.x1)
        width = height * img_ratio
        x0 = x_center - width / 2.0

        ax_probe.set_position([x0, y0, width, height])
        ax_probe.set_aspect('equal')

    # ---- Text for row 0 ------------------------------

    # Probe label underneath
    bbox = ax_probe.get_position()
    # Add asterisk after target class *only*
    true_str = f"{CLASS_NAMES[true_label]}" + ("*" if true_label == target_class else "")
    target_str = f"{CLASS_NAMES[target_class]}*"
    fig.text(
        (bbox.x0 + bbox.x1) / 2,
        bbox.y0 - 0.02,
        f"True: {true_str}, Target: {target_str}",
        ha='center', va='top', fontsize=8
    )

    # Row labels between probe and grid
    if ax_row0 is not None:
        bbox_probe = ax_probe.get_position()
        bbox0 = ax_row0.get_position()
        bbox1 = ax_row1.get_position()
        bbox2 = ax_row2.get_position()

        x_label = (bbox_probe.x1 + bbox0.x0) / 2.0

        y0 = (bbox0.y0 + bbox0.y1) / 2.0
        y1 = (bbox1.y0 + bbox1.y1) / 2.0
        y2 = (bbox2.y0 + bbox2.y1) / 2.0

        fig.text(x_label, y0, 'Original',
                 fontsize=8, va='center', ha='center', rotation=90)
        fig.text(x_label, y1, 'Perturbed',
                 fontsize=8, va='center', ha='center', rotation=90)
        fig.text(x_label, y2, 'Difference (x5)',
                 fontsize=8, va='center', ha='center', rotation=90)

    # Column labels under each right-hand column, with asterisk if target class
    for i in range(n_show):
        ax_diff = ax_grid[i][2]
        bbox = ax_diff.get_position()
        x = (bbox.x0 + bbox.x1) / 2
        y = bbox.y0 - 0.015
        fig.text(x, y, col_labels[i],
                 ha='center', va='top', fontsize=8)

    # ===== ROW 1: Bar Chart =====
    ax_bar = fig.add_subplot(gs_main[1, 0])
    
    x = np.arange(K)
    width = 0.35

    # Determine colors for each class: blue for true, red for target, green for others
    colors_pre = []
    colors_post = []
    for class_idx in range(K):
        if class_idx == true_label:
            colors_pre.append('blue')
            colors_post.append('blue')
        elif class_idx == target_class:
            colors_pre.append('red')
            colors_post.append('red')
        else:
            colors_pre.append('green')
            colors_post.append('green')

    # Don't use labels in bar() - we'll create custom legend
    bars1 = ax_bar.bar(x - width/2, p_pre, width,
                       color=colors_pre, alpha=0.8)
    bars2 = ax_bar.bar(x + width/2, p_post, width,
                       color=colors_post, alpha=0.5)

    # --- Highlight the target class x tick label with asterisk ---
    xtick_labels = [c for c in CLASS_NAMES]
    xticks_colored = []
    for xc_idx, label in enumerate(xtick_labels):
        if xc_idx == target_class:
            xticks_colored.append(f"{label}*")
        else:
            xticks_colored.append(label)

    ax_bar.set_xlabel('Class')
    ax_bar.set_ylabel('Probability')
    ax_bar.set_title(f'Probability Distribution')
    ax_bar.set_xticks(x)
    ax_bar.set_xticklabels(xticks_colored, rotation=45, ha='right', fontsize=9)
    
    # Create custom legend with gray patches
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='gray', alpha=0.8, edgecolor='black', label='Original'),
        Patch(facecolor='gray', alpha=0.5, edgecolor='black', label='Infused')
    ]
    ax_bar.legend(handles=legend_elements, loc='upper right', fontsize=8)
    ax_bar.grid(axis='y', alpha=0.3)

    # Center the bar plot across the entire figure width
    bbox_bar = ax_bar.get_position()
    
    # Use the figure's left and right margins
    fig_center = 0.5  # Center of the figure
    bar_width = 0.9  # 90% of the total figure width
    bar_x0 = fig_center - bar_width / 2.0
    
    ax_bar.set_position([bar_x0, bbox_bar.y0, bar_width, bbox_bar.height])

    # ===== ROW 2: Timeline of Perturbed Documents =====
    ax_timeline = fig.add_subplot(gs_main[2, 0])
    
    # Get the training set size (total number of training examples)
    train_size = 45000  # CIFAR-10 training set size
    
    # Normalize indices to [0, 1] range
    normalized_positions = np.array(selected_train_indices) / train_size
    
    # Draw a rectangle representing the full training sequence
    # Adjust rectangle position to leave more room at bottom for legend
    ax_timeline.add_patch(Rectangle((0, 0.4), 1, 0.4, 
                                   facecolor='lightgray', edgecolor='black', linewidth=1))
    
    # Plot vertical lines for ALL perturbed documents (not just the top n_show)
    # Color code: red for target class, blue for true class, green for others
    for i, pos in enumerate(normalized_positions):  # Loop through ALL perturbed documents
        label_i = original_train_labels[i]
        train_class_idx = int(label_i) if isinstance(label_i, (int, np.integer)) else None
        
        if train_class_idx is not None and train_class_idx == target_class:
            color = 'red'
        elif train_class_idx is not None and train_class_idx == true_label:
            color = 'blue'
        else:
            color = 'green'
        
        ax_timeline.plot([pos, pos], [0.4, 0.8], color=color, linewidth=2, alpha=0.7)
    
    ax_timeline.set_xlim([0, 1])
    ax_timeline.set_ylim([0, 1])
    ax_timeline.set_xlabel('Position in Training Data', fontsize=9)
    ax_timeline.set_title(f'Location of Perturbed Documents in Training Sequence (n={len(normalized_positions)})', fontsize=9)
    ax_timeline.set_yticks([])
    ax_timeline.set_xticks([0, 0.25, 0.5, 0.75, 1.0])
    ax_timeline.set_xticklabels(['Start', '25%', '50%', '75%', 'End'], fontsize=8)
    
    # Add legend for the timeline - positioned lower to avoid overlap
    from matplotlib.lines import Line2D
    legend_elements_timeline = [
        Line2D([0], [0], color='red', linewidth=2, label='Target class'),
        Line2D([0], [0], color='blue', linewidth=2, label='True class'),
        Line2D([0], [0], color='green', linewidth=2, label='Other classes')
    ]
    ax_timeline.legend(handles=legend_elements_timeline, loc='lower right', fontsize=7, ncol=3, 
                      bbox_to_anchor=(1.0, 0.0), framealpha=0.95)
    
    # Center the timeline across the figure width to match the bar chart
    bbox_timeline = ax_timeline.get_position()
    ax_timeline.set_position([bar_x0, bbox_timeline.y0, bar_width, bbox_timeline.height])

    return fig


# Generate the figure with timeline for a selected example
import os

sorted_results = sorted(all_results, key=lambda x: x['delta_p'], reverse=False)
figures_dir = "figures"
os.makedirs(figures_dir, exist_ok=True)


# for example_best in sorted_results[:10]:
    
    
#     fig3 = create_influence_figure_with_timeline(example_best, n_show=5)

#     # # Save the figure
#     # fig3.savefig(os.path.join(figures_dir, "influence_figure_with_timeline.png"), bbox_inches='tight', dpi=200)
#     # fig3.savefig(os.path.join(figures_dir, "influence_figure_with_timeline.eps"), bbox_inches='tight', dpi=200)

#     print("Figure with timeline saved!")
#     print(f"Number of perturbed documents shown: {len(example_best['result']['selected_train_indices'])}")
#     plt.show()

# %%
# Create scatter plot with box plots showing distributions
# Collect all probability data points across all examples

prob_original = []
prob_infused = []
point_types = []  # 'target', 'true', or 'other'

for example in all_results:
    p_pre = example['p_pre']
    p_post = example['p_post']
    target_class = example['target_class']
    true_label = example['true_label']
    
    for class_idx in range(K):
        prob_original.append(p_pre[class_idx])
        prob_infused.append(p_post[class_idx])
        
        if class_idx == target_class:
            point_types.append('target')
        elif class_idx == true_label:
            point_types.append('true')
        else:
            point_types.append('other')

# Convert to arrays
prob_original = np.array(prob_original)
prob_infused = np.array(prob_infused)
point_types = np.array(point_types)

# Create figure with GridSpec for precise control
fig = plt.figure(figsize=(8, 4))
gs = gridspec.GridSpec(1, 2, figure=fig, wspace=0.3)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

# ===== LEFT PANEL: Scatter Plot =====
# Plot different categories with different colors
mask_other = point_types == 'other'
mask_true = point_types == 'true'
mask_target = point_types == 'target'

sc_other = ax1.scatter(prob_original[mask_other], prob_infused[mask_other], 
           c='green', alpha=0.3, s=10, label='Other classes', rasterized=True)
sc_true = ax1.scatter(prob_original[mask_true], prob_infused[mask_true], 
           c='blue', alpha=0.3, s=10, label='True class', rasterized=True)
sc_target = ax1.scatter(prob_original[mask_target], prob_infused[mask_target], 
           c='red', alpha=0.3, s=10, label='Target class', rasterized=True)

# Add diagonal line (y=x) for reference
line_yx, = ax1.plot([0, 1], [0, 1], 'k--', linewidth=1, alpha=0.5, label='y=x (no change)')

ax1.set_xlabel('Original Probability', fontsize=8)
ax1.set_ylabel('Infused Probability', fontsize=8)
# ax1.set_title('Probability Changes: Original vs Infused', fontsize=11)

# Reorder legend: True class, Target class, Other classes, y=x (no change)
handles = [sc_true, sc_target, sc_other, line_yx]
labels = ['True class', 'Target class', 'Other classes', 'y=x (no change)']
ax1.legend(handles, labels, loc='upper right', fontsize=8)

ax1.grid(alpha=0.3)
ax1.set_xlim([0, 1])
ax1.set_ylim([0, 1])
ax1.set_aspect('equal', adjustable='box')

# ===== RIGHT PANEL: Box Plots =====
# Prepare data for box plots
data_to_plot = [
    prob_original[mask_true], prob_infused[mask_true],
    prob_original[mask_target], prob_infused[mask_target],
    prob_original[mask_other], prob_infused[mask_other]
]

positions = [1, 1.8, 3, 3.8, 5, 5.8]
# Match category colors: blue, blue, red, red, green, green
colors = ['blue', 'blue', 'red', 'red', 'green', 'green']
alphas = [0.8, 0.5, 0.8, 0.5, 0.8, 0.5]

# Create box plots with 5th and 95th percentile whiskers, no outliers shown
bp = ax2.boxplot(data_to_plot, positions=positions, widths=0.6,
                 patch_artist=True, showmeans=True, showfliers=False,
                 whis=[5, 95],  # Whiskers at 5th and 95th percentiles
                 meanprops=dict(marker='D', markerfacecolor='black', markeredgecolor='black', markersize=4),
                 medianprops=dict(color='black', linewidth=1),
                 boxprops=dict(linewidth=1),
                 whiskerprops=dict(linewidth=1),
                 capprops=dict(linewidth=1))

# Color the boxes
for patch, color, alpha in zip(bp['boxes'], colors, alphas):
    patch.set_facecolor(color)
    patch.set_alpha(alpha)

# Add labels
ax2.set_xticks([1.4, 3.4, 5.4])
ax2.set_xticklabels(['True Class', 'Target Class', 'Other Classes'])
ax2.set_ylabel('Probability', fontsize=8)
# ax2.set_title('Probability Distributions: Before vs After Infusion', fontsize=11)
ax2.grid(axis='y', alpha=0.3)
ax2.set_ylim([0, 1])
ax2.set_xlim([0, 7])

# Add custom legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='gray', alpha=0.8, edgecolor='black', label='Before Infusion'),
    Patch(facecolor='gray', alpha=0.5, edgecolor='black', label='After Infusion')
]
ax2.legend(handles=legend_elements, loc='upper right', fontsize=8)

# Removed vertical dotted lines to separate categories

# Match the y-axis heights by getting ax1's position and applying to ax2
fig.canvas.draw()  # Force draw to get accurate positions
pos1 = ax1.get_position()
pos2 = ax2.get_position()

# Align ax2's y-axis with ax1
ax2.set_position([pos2.x0, pos1.y0, pos2.width, pos1.height])

plt.savefig('figures/scatter_and_boxplots_probability.eps', bbox_inches='tight', dpi=300)
plt.savefig('figures/scatter_and_boxplots_probability.png', bbox_inches='tight', dpi=300)
print("\nCombined plot saved to figures/scatter_and_boxplots_probability.pdf")

# Print statistics
print(f"\nStatistics:")
print(f"Total points: {len(prob_original)}")
print(f"Target class points: {mask_target.sum()}")
print(f"True class points: {mask_true.sum()}")
print(f"Other class points: {mask_other.sum()}")

# Calculate medians and means
print(f"\nMedian probabilities:")
print(f"  True class:    Before={np.median(prob_original[mask_true]):.4f}, After={np.median(prob_infused[mask_true]):.4f}")
print(f"  Target class:  Before={np.median(prob_original[mask_target]):.4f}, After={np.median(prob_infused[mask_target]):.4f}")
print(f"  Other classes: Before={np.median(prob_original[mask_other]):.4f}, After={np.median(prob_infused[mask_other]):.4f}")

print(f"\nMean probabilities:")
print(f"  True class:    Before={prob_original[mask_true].mean():.4f}, After={prob_infused[mask_true].mean():.4f}")
print(f"  Target class:  Before={prob_original[mask_target].mean():.4f}, After={prob_infused[mask_target].mean():.4f}")
print(f"  Other classes: Before={prob_original[mask_other].mean():.4f}, After={prob_infused[mask_other].mean():.4f}")

print(f"\nMean probability change:")
print(f"  True class:    {prob_infused[mask_true].mean() - prob_original[mask_true].mean():+.4f}")
print(f"  Target class:  {prob_infused[mask_target].mean() - prob_original[mask_target].mean():+.4f}")
print(f"  Other classes: {prob_infused[mask_other].mean() - prob_original[mask_other].mean():+.4f}")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Combined plot saved to figures/scatter_and_boxplots_probability.pdf
#
# Statistics:
# Total points: 20000
# Target class points: 2000
# True class points: 1800
# Other class points: 16200
#
# Median probabilities:
#   True class:    Before=0.8692, After=0.3334
#   Target class:  Before=0.0008, After=0.1367
#   Other classes: Before=0.0004, After=0.0021
#
# Mean probabilities:
#   True class:    Before=0.7381, After=0.3960
#   Target class:  Before=0.1000, After=0.3322
#   Other classes: Before=0.0291, After=0.0384
#
# Mean probability change:
#   True class:    -0.3421
#   Target class:  +0.2322
#   Other classes: +0.0093

# %%
# Create heatmap + box plots showing distributions
# Collect all probability data points across all examples
#  THIS CELL

import seaborn as sns
from matplotlib.patches import Patch, PathPatch
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LinearSegmentedColormap  # <--- for the custom colormap

prob_original = []
prob_infused = []
point_types = []

for example in all_results:
    p_pre = example['p_pre']
    p_post = example['p_post']
    target_class = example['target_class']
    true_label = example['true_label']
    
    for class_idx in range(K):
        prob_original.append(p_pre[class_idx])
        prob_infused.append(p_post[class_idx])
        
        if class_idx == target_class:
            point_types.append('target')
        elif class_idx == true_label:
            point_types.append('true')
        else:
            point_types.append('other')

prob_original = np.array(prob_original)
prob_infused = np.array(prob_infused)
point_types = np.array(point_types)

mask_other = point_types == 'other'
mask_true = point_types == 'true'
mask_target = point_types == 'target'

# ===== Build 10x10 heatmap: mean delta p(target) for each (true_label, target_class) =====
heatmap_pre = np.zeros((K, K))
heatmap_post = np.zeros((K, K))
heatmap_counts = np.zeros((K, K))

for example in all_results:
    tl = example['true_label']
    tc = example['target_class']
    heatmap_pre[tl, tc] += example['p_pre'][tc]
    heatmap_post[tl, tc] += example['p_post'][tc]
    heatmap_counts[tl, tc] += 1

with np.errstate(divide='ignore', invalid='ignore'):
    heatmap_mean_delta = np.where(
        heatmap_counts > 0,
        (heatmap_post - heatmap_pre) / heatmap_counts,
        np.nan
    )

# --- Standardised style constants ---
LABEL_SIZE = 8
TICK_SIZE = 7
LEGEND_SIZE = 7
ANNOT_SIZE = 6
LINE_WIDTH = 0.8

# Muted, publication-quality colours
COL_TRUE   = '#4878CF'  # steel blue
COL_TARGET = '#D65F5F'  # muted red
COL_OTHER  = '#6ACC65'  # soft green

# --- Define diverging colormap: blue (negative) --> white (zero) --> red (positive) ---
cmap = LinearSegmentedColormap.from_list(
    'blue_white_red',
    [(0, '#4575b4'), (0.5, '#ffffff'), (1, '#d73027')]
)

sns.set_theme(style='ticks', context='paper', rc={
    'axes.linewidth': LINE_WIDTH,
    'xtick.major.width': LINE_WIDTH,
    'ytick.major.width': LINE_WIDTH,
    'xtick.major.size': 3,
    'ytick.major.size': 3,
})

fig = plt.figure(figsize=(9, 4))
gs = gridspec.GridSpec(1, 2, figure=fig, wspace=0.55,
                       width_ratios=[1, 1.1])
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

# ===== LEFT PANEL: Seaborn Heatmap (perfectly square) =====
heatmap_df = pd.DataFrame(heatmap_mean_delta, index=CLASS_NAMES, columns=CLASS_NAMES)
mask_nan = np.isnan(heatmap_mean_delta)

sns.heatmap(heatmap_df, ax=ax1, mask=mask_nan,
            cmap=cmap, center=0, vmin=-1, vmax=1,
            square=True,
            annot=True, fmt='.1f',
            annot_kws={'size': ANNOT_SIZE},
            linewidths=0.5, linecolor='white',
            cbar=False)

ax1.set_xlabel('Target Class', fontsize=LABEL_SIZE)
ax1.set_ylabel('True Class', fontsize=LABEL_SIZE)
ax1.tick_params(labelsize=TICK_SIZE, length=0)

# Rotate x-tick labels diagonally
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right',
                    rotation_mode='anchor')

# Add colorbar that spans the full height of the heatmap axes
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.08)
cbar = fig.colorbar(ax1.collections[0], cax=cax)
cbar.set_label('Mean $\\Delta$P(target)', fontsize=LABEL_SIZE)
cbar.ax.tick_params(labelsize=TICK_SIZE, width=LINE_WIDTH, length=3)
cbar.outline.set_linewidth(LINE_WIDTH)

# ===== RIGHT PANEL: Seaborn Box Plots =====
box_df = pd.DataFrame({
    'Probability': np.concatenate([
        prob_original[mask_true], prob_infused[mask_true],
        prob_original[mask_target], prob_infused[mask_target],
        prob_original[mask_other], prob_infused[mask_other]
    ]),
    'Category': (
        ['True Class'] * mask_true.sum() + ['True Class'] * mask_true.sum() +
        ['Target Class'] * mask_target.sum() + ['Target Class'] * mask_target.sum() +
        ['Other Classes'] * mask_other.sum() + ['Other Classes'] * mask_other.sum()
    ),
    'Condition': (
        ['Before'] * mask_true.sum() + ['After'] * mask_true.sum() +
        ['Before'] * mask_target.sum() + ['After'] * mask_target.sum() +
        ['Before'] * mask_other.sum() + ['After'] * mask_other.sum()
    )
})

sns.boxplot(data=box_df, x='Category', y='Probability', hue='Condition',
            order=['True Class', 'Target Class', 'Other Classes'],
            hue_order=['Before', 'After'],
            ax=ax2, whis=[5, 95], showfliers=False,
            showmeans=True,
            meanprops=dict(marker='D', markerfacecolor='white',
                           markeredgecolor='black', markersize=3,
                           markeredgewidth=LINE_WIDTH, zorder=5),
            medianprops=dict(color='black', linewidth=LINE_WIDTH),
            whiskerprops=dict(linewidth=LINE_WIDTH, color='0.4'),
            capprops=dict(linewidth=LINE_WIDTH, color='0.4'),
            width=0.55, linewidth=LINE_WIDTH,
            saturation=0.85, gap=0.15)

# Recolour boxes by category and add hatching for "After"
cat_colors = [COL_TRUE, COL_TRUE, COL_TARGET, COL_TARGET, COL_OTHER, COL_OTHER]
hatches_list = ['', '///', '', '///', '', '///']

boxes = sorted(
    [p for p in ax2.patches if isinstance(p, PathPatch)],
    key=lambda p: p.get_path().vertices[:, 0].mean()
)

for box, color, hatch in zip(boxes, cat_colors, hatches_list):
    box.set_facecolor(color)
    box.set_alpha(0.85)
    box.set_edgecolor('0.25')
    box.set_linewidth(LINE_WIDTH)
    box.set_hatch(hatch)

# Replace seaborn's auto-legend with custom hatched legend
if ax2.get_legend() is not None:
    ax2.get_legend().remove()

legend_elements = [
    Patch(facecolor='0.65', alpha=0.85, edgecolor='0.25',
          linewidth=LINE_WIDTH, label='Before Infusion'),
    Patch(facecolor='0.65', alpha=0.85, edgecolor='0.25',
          linewidth=LINE_WIDTH, hatch='///', label='After Infusion')
]
leg = ax2.legend(handles=legend_elements, loc='upper right',
                 fontsize=LEGEND_SIZE, frameon=True, edgecolor='0.8',
                 fancybox=False, framealpha=0.9)
leg.get_frame().set_linewidth(LINE_WIDTH)

ax2.set_xlabel('')
ax2.set_ylabel('Probability', fontsize=LABEL_SIZE)
ax2.tick_params(labelsize=TICK_SIZE)
ax2.set_ylim([0, 1.02])
ax2.yaxis.set_major_locator(plt.MultipleLocator(0.2))
ax2.yaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax2.grid(axis='y', which='major', alpha=0.25, linewidth=LINE_WIDTH, color='0.7')
ax2.grid(axis='y', which='minor', alpha=0.12, linewidth=LINE_WIDTH * 0.5,
         color='0.7', linestyle=':')
ax2.set_axisbelow(True)
sns.despine(ax=ax2, left=False, bottom=False)

# Align panel heights: match boxplot to heatmap
fig.canvas.draw()
pos1 = ax1.get_position()
pos2 = ax2.get_position()
ax2.set_position([pos2.x0, pos1.y0, pos2.width, pos1.height])

plt.savefig('figures/heatmap_and_boxplots_probability.eps', bbox_inches='tight', dpi=300)
plt.savefig('figures/heatmap_and_boxplots_probability.png', bbox_inches='tight', dpi=300)
print("\nCombined plot saved to figures/heatmap_and_boxplots_probability.{eps,png}")

# Print statistics
print(f"\nStatistics:")
print(f"Total points: {len(prob_original)}")
print(f"Target class points: {mask_target.sum()}")
print(f"True class points: {mask_true.sum()}")
print(f"Other class points: {mask_other.sum()}")

# Heatmap statistics
print(f"\nHeatmap (mean delta P(target)) summary:")
off_diag = heatmap_mean_delta[~np.eye(K, dtype=bool)]
diag = np.diag(heatmap_mean_delta)
print(f"  Diagonal (true==target):     mean={np.nanmean(diag):+.4f}, min={np.nanmin(diag):+.4f}, max={np.nanmax(diag):+.4f}")
print(f"  Off-diagonal (true!=target): mean={np.nanmean(off_diag):+.4f}, min={np.nanmin(off_diag):+.4f}, max={np.nanmax(off_diag):+.4f}")

# Calculate medians and means
print(f"\nMedian probabilities:")
print(f"  True class:    Before={np.median(prob_original[mask_true]):.4f}, After={np.median(prob_infused[mask_true]):.4f}")
print(f"  Target class:  Before={np.median(prob_original[mask_target]):.4f}, After={np.median(prob_infused[mask_target]):.4f}")
print(f"  Other classes: Before={np.median(prob_original[mask_other]):.4f}, After={np.median(prob_infused[mask_other]):.4f}")

print(f"\nMean probabilities:")
print(f"  True class:    Before={prob_original[mask_true].mean():.4f}, After={prob_infused[mask_true].mean():.4f}")
print(f"  Target class:  Before={prob_original[mask_target].mean():.4f}, After={prob_infused[mask_target].mean():.4f}")
print(f"  Other classes: Before={prob_original[mask_other].mean():.4f}, After={prob_infused[mask_other].mean():.4f}")

print(f"\nMean probability change:")
print(f"  True class:    {prob_infused[mask_true].mean() - prob_original[mask_true].mean():+.4f}")
print(f"  Target class:  {prob_infused[mask_target].mean() - prob_original[mask_target].mean():+.4f}")
print(f"  Other classes: {prob_infused[mask_other].mean() - prob_original[mask_other].mean():+.4f}")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Combined plot saved to figures/heatmap_and_boxplots_probability.{eps,png}
#
# Statistics:
# Total points: 20000
# Target class points: 2000
# True class points: 1800
# Other class points: 16200
#
# Heatmap (mean delta P(target)) summary:
#   Diagonal (true==target):     mean=+0.2150, min=+0.0673, max=+0.3615
#   Off-diagonal (true!=target): mean=+0.2267, min=+0.0085, max=+0.6547
#
# Median probabilities:
#   True class:    Before=0.8692, After=0.3334
#   Target class:  Before=0.0008, After=0.1367
#   Other classes: Before=0.0004, After=0.0021
#
# Mean probabilities:
#   True class:    Before=0.7381, After=0.3960
#   Target class:  Before=0.1000, After=0.3322
#   Other classes: Before=0.0291, After=0.0384
#
# Mean probability change:
#   True class:    -0.3421
#   Target class:  +0.2322
#   Other classes: +0.0093
